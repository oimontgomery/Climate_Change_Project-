# %%
import pandas as pd
from datetime import datetime

# %%
tdf=pd.read_csv("GlobalLandTemperaturesByCountry.csv",encoding="utf8")
tdf.tail()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 577457  Zimbabwe
# 577458  Zimbabwe
# 577459  Zimbabwe
# 577460  Zimbabwe
# 577461  Zimbabwe

# %%
ustdf=tdf.loc[(tdf["Country"]=='United States'),:]
ustdf.tail()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 557816  2013-05-01              14.073                          0.178
# 557817  2013-06-01              20.198                          0.236
# 557818  2013-07-01              22.074                          0.152
# 557819  2013-08-01              21.168                          0.249
# 557820  2013-09-01              18.273                          1.210
#
#               Country
# 557816  United States
# 557817  United States
# 557818  United States
# 557819  United States
# 557820  United States

# %%
ustdf=ustdf.dropna(how="any")
ustdf.head(20)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 554880  1768-09-01              15.420                          2.880
# 554881  1768-10-01               8.162                          3.386
# 554882  1768-11-01               1.591                          3.783
# 554883  1768-12-01              -2.882                          4.979
# 554884  1769-01-01              -3.952                          4.856
# 554885  1769-02-01              -2.684                          3.311
# 554886  1769-03-01               1.828                          3.884
# 554887  1769-04-01               8.843                          3.482
# 554888  1769-05-01              15.724                          4.795
# 554889  1769-06-01              20.933                          2.613
# 554890  1769-07-01              22.093                          3.277
# 554891  1769-08-01              20.787                          3.329
# ...

# %%
ustdf["Year"]=ustdf["dt"]
ustdf.head()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 554880  1768-09-01              15.420                          2.880
# 554881  1768-10-01               8.162                          3.386
# 554882  1768-11-01               1.591                          3.783
# 554883  1768-12-01              -2.882                          4.979
# 554884  1769-01-01              -3.952                          4.856
#
#               Country        Year
# 554880  United States  1768-09-01
# 554881  United States  1768-10-01
# 554882  United States  1768-11-01
# 554883  United States  1768-12-01
# 554884  United States  1769-01-01

# %%
ustdf=ustdf.reset_index(drop=True)
ustdf.tail()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2477  2013-05-01              14.073                          0.178
# 2478  2013-06-01              20.198                          0.236
# 2479  2013-07-01              22.074                          0.152
# 2480  2013-08-01              21.168                          0.249
# 2481  2013-09-01              18.273                          1.210
#
#             Country        Year
# 2477  United States  2013-05-01
# 2478  United States  2013-06-01
# 2479  United States  2013-07-01
# 2480  United States  2013-08-01
# 2481  United States  2013-09-01

# %%
rows_count=ustdf["Year"].count()
rows_count
# Out:
# 2482

# %%
for i in range(0,rows_count):
    ustdf["Year"][i]=ustdf["Year"][i][0:4]
# Out:
# C:\Users\Sean Lei\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
gdf.to_csv("Tem_by_Year.csv",index=True,header=True)

# %%
ustdf.tail()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2477  2013-05-01              14.073                          0.178
# 2478  2013-06-01              20.198                          0.236
# 2479  2013-07-01              22.074                          0.152
# 2480  2013-08-01              21.168                          0.249
# 2481  2013-09-01              18.273                          1.210
#
#             Country  Year
# 2477  United States  2013
# 2478  United States  2013
# 2479  United States  2013
# 2480  United States  2013
# 2481  United States  2013

# %%
ustdf["Avg_Temp(Farenheit)"]=(ustdf["AverageTemperature"]*9/5)+32
ustdf.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0  1768-09-01              15.420                          2.880
# 1  1768-10-01               8.162                          3.386
# 2  1768-11-01               1.591                          3.783
# 3  1768-12-01              -2.882                          4.979
# 4  1769-01-01              -3.952                          4.856
#
#          Country  Year  Avg_Temp(Farenheit)
# 0  United States  1768              59.7560
# 1  United States  1768              46.6916
# 2  United States  1768              34.8638
# 3  United States  1768              26.8124
# 4  United States  1769              24.8864

# %%
gdf=ustdf.groupby("Year")
gdf=pd.DataFrame(gdf["Avg_Temp(Farenheit)"].mean())

# %%
gdf.to_csv("Temp_by_Year.csv",index=True,header=True)
